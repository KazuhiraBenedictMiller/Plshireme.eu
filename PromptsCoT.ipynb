# %% [markdown]
# # **Chain of Thought Prompt Engineering Strategy for Finance LLM**

# %% [markdown]
# ---

# %% [markdown]
# ### **Chain of Thought Process Generation:**

# %% [markdown]
# You are a Financial Markets Trader and Analyst, your job is to look at price action fluctuations, and after you've elaborated them, to return a technical summary of what happened throughout the trading day.
# To achieve this goal, the first step is to divide the Final Goal of returning a Technical Summary to the user into smaller standalone task, and then to merge them together.
# That being said, return what are the 5 things you would look out for in a BTCUSD chart, considering that the Dataset you'll be given will be in this format:
#
# Date, ZigZag Indicator
#
# Where Date is the date when the ZigZag Indicator Swing has completed, and ZigZag Indicator is the actual Point of Swing from the Previous ZigZag Point.
# The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
# The returned answer should be in a bullet list format, where every point starts with a "-" sign and there is a "\n" dividing each point of the bullet list.
# Return only the Bullet list without adding anything before and after it.

# %% [markdown]
# ---

# %% [markdown]
# ### **Parameters, SystemPrompt, StepsQuestions, DatasetContext**
#
# **PARAMS**
#
# temperature = 0.9 / 0.8\
# top_p = 0.9 / 1\
# max_tokens = 8192\
# seed = 7688\
# model = llama3-70b-8192
#
# **SystemPrompt**
#
# You are a Financial Markets Trader and Analyst, your job is to look at price action fluctuations, and after you've digested and analysed them, to return an elaborated technical summary of what happened throughout the trading day based on the user request.\
# More specifically, your task is, given a simple narrow request to generate a neutral technical summary based on the request made by the user, without giving any suggestions or investment advice to potential traders and investors.
#
# **SystemPromptBis**
#
# You are a Financial Markets Trader and Analyst, your job is to look at price action fluctuations, and after you've digested and analysed them, to return an elaborated technical summary of what happened throughout the trading day based on the user request.\
# More specifically, your task is, given a simple narrow request and some contextual data, to generate a neutral technical summary based on the request made by the user, without giving any suggestions or investment advice to potential traders and investors.
#
# **SystemPromptTris**
#
# You are a Financial Markets Trader and Analyst, and your job is to look at and interpret price action fluctuations.\
# Then, after you've digested and analysed them, you will return an elaborated technical summary of what happened throughout the trading day based on the user request.\
# More specifically, your task is, given a simple narrow request and some contextual data, to generate a neutral technical analysis summary based on the request made by the user, without giving any suggestions or investment advice to potential traders and investors.
#
# **StepsQuestion**
#
# **1**\
# Identify key levels of support and resistance by analyzing the frequency and clustering of ZigZag Indicator values around specific price levels.\
# The support and resistance levels should not be too precise, instead, they need to be rounded up or down, highlighting the support or resistance area, rather than a single specific value.
#
# **1.1**\
# Identify key levels of support and resistance by analyzing the frequency and clustering of ZigZag Indicator values around specific price levels.\
# The support and resistance levels should not be too precise, instead, they need to be rounded up or down, highlighting the support or resistance area, rather than a single specific value.\
# You should also point out how many times the given support or resistance level has been touched, to emphasize its strength and importance.
#
# **1.2**\
# Identify key levels of price that have been support and resistance by analyzing the frequency and clustering of ZigZag Indicator values around specific price levels.\
# The support and resistance price levels should not be too precise, instead, they need to be rounded up or down, rather than a single specific value.\
# You should also point out how many times the given support or resistance price level has been touched, to emphasize its strength and importance.
#
# **2**\
# Look for areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range, which can indicate a potential breakout or reversal, or simply a trading a range.
#
# **2.1**\
# Look for all areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range, which can indicate a potential breakout or reversal, or simply a trading a range.\
# The identified consolidation or congestion areas should not be too precise, instead, they need to be rounded up or down, indicating an area, rather than a single specific value.\
# You should also point out what kind of consolidation or congestion happened in that specific area, taking as context the previous movement that preceded the consolidation or congestion and how much time the price has spent in that area.
#
# **2.2**\
# Look for all areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range, which can indicate a potential breakout or reversal, or simply a trading a range.\
# The identified consolidation or congestion areas should not be too precise, instead, they need to be rounded up or down, indicating an area, rather than a single specific value.\
# You should also point out what kind of consolidation or congestion happened in that specific area, taking as context the previous movement that preceded the consolidation or congestion and the date when the consolidation or congestion started as well as how much time the price has spent in that Area.
#
# **DatasetContext**
#
# **Close-Close ZigZag**\
# 2024-03-11 00:00:00, 69020.55\
# 2024-03-13 00:00:00, 73083.5\
# 2024-03-16 00:00:00, 65315.12\
# 2024-03-17 00:00:00, 68390.62\
# 2024-03-19 00:00:00, 61912.77\
# 2024-03-20 00:00:00, 67913.67\
# 2024-03-22 00:00:00, 63778.76\
# 2024-03-25 00:00:00, 69958.81\
# 2024-04-02 00:00:00, 65446.97\
# 2024-04-08 00:00:00, 71631.36\
# 2024-04-09 00:00:00, 69139.02\
# 2024-04-10 00:00:00, 70587.88\
# 2024-04-13 00:00:00, 63821.47\
# 2024-04-14 00:00:00, 65738.73\
# 2024-04-17 00:00:00, 61276.69\
# 2024-04-22 00:00:00, 66837.68\
# 2024-05-01 00:00:00, 58254.01\
# 2024-05-03 00:00:00, 62889.84\
# 2024-05-08 00:00:00, 61187.94\
# 2024-05-09 00:00:00, 63049.96\
# 2024-05-10 00:00:00, 60792.78\
# 2024-05-13 00:00:00, 62901.45\
# 2024-05-14 00:00:00, 61552.79\
# 2024-05-20 00:00:00, 71448.2\
# 2024-05-29 00:00:00, 67578.09\
# 2024-06-04 00:00:00, 70567.77\
# 2024-06-18 00:00:00, 65632.84
#
# **High-Low ZigZag**\
# 2024-03-11 00:00:00, 69020.55\
# 2024-03-14 00:00:00, 73750.07\
# 2024-03-17 00:00:00, 64545.32\
# 2024-03-18 00:00:00, 68897.13\
# 2024-03-20 00:00:00, 60807.79\
# 2024-03-21 00:00:00, 68199.99\
# 2024-03-22 00:00:00, 62355.37\
# 2024-03-27 00:00:00, 71727.69\
# 2024-03-28 00:00:00, 68895.51\
# 2024-03-31 00:00:00, 71377.78\
# 2024-04-03 00:00:00, 64559.9\
# 2024-04-04 00:00:00, 69291.26\
# 2024-04-05 00:00:00, 66011.48\
# 2024-04-08 00:00:00, 72715.36\
# 2024-04-10 00:00:00, 67503.56\
# 2024-04-11 00:00:00, 71256.23\
# 2024-04-13 00:00:00, 60919.11\
# 2024-04-15 00:00:00, 66878.65\
# 2024-04-17 00:00:00, 59768.59\
# 2024-04-19 00:00:00, 65481.6\
# 2024-04-20 00:00:00, 63172.4\
# 2024-04-22 00:00:00, 67233.96\
# 2024-04-25 00:00:00, 62783.63\
# 2024-04-26 00:00:00, 64789.66\
# 2024-04-27 00:00:00, 62424.72\
# 2024-04-28 00:00:00, 64321.48\
# 2024-05-01 00:00:00, 56555.29\
# 2024-05-06 00:00:00, 65494.9\
# 2024-05-10 00:00:00, 60208.78\
# 2024-05-13 00:00:00, 63422.66\
# 2024-05-14 00:00:00, 61123.77\
# 2024-05-21 00:00:00, 71946.46\
# 2024-05-23 00:00:00, 66356.95\
# 2024-05-25 00:00:00, 69579.32\
# 2024-05-26 00:00:00, 68183.89\
# 2024-05-27 00:00:00, 70597.88\
# 2024-05-29 00:00:00, 67101.49\
# 2024-05-30 00:00:00, 69500.54\
# 2024-05-31 00:00:00, 66633.42\
# 2024-06-05 00:00:00, 71735.41\
# 2024-06-07 00:00:00, 68507.26\
# 2024-06-10 00:00:00, 70146.07\
# 2024-06-11 00:00:00, 66123.6\
# 2024-06-12 00:00:00, 69977.89\
# 2024-06-14 00:00:00, 65056.89\
# 2024-06-17 00:00:00, 67188.32\
# 2024-06-18 00:00:00, 64637.63

# %% [markdown]
# ---

# %% [markdown]
# # **Notes on the Approach below for CoT First Node (First Attempt):**
#
# This strategy seems to perform well on the given ZigZag Indicator Data.\
# BUT, even if it works very well on ZigZag Indicator Data on Close Prices, I think it can work so much better on ZigZag Indicator Data on High-Low Prices and a bit more Prompt Engineering.

# %% [markdown]
# ### **Chain of Thought First Node:**

# %% [markdown]
# **First Node Template**
#
# What you need to look out for at this stage, is:
#
# {question}
#
# The Dataset you'll be given will be in this format:
#
# Date, ZigZagIndicator
#
# Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the previous ZigZag Point.\
# The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
#
# Here's the Dataset:
#
# Date, ZigZagIndicator
#
# {context}
#
# Return the answer and the answer only, without adding anything before and after it.

# %% [markdown]
# **First Node Complete**
#
# What you need to look out for at this stage, is:
#
# Identify key levels of support and resistance by analyzing the frequency and clustering of ZigZag Indicator values around specific price levels.\
# The support and resistance levels should not be too precise, instead, they need to be rounded up or down, highlighting the support or resistance area, rather than a single specific value.\
# You should also point out how many times the given support or resistance level has been touched, to emphasize its strength and importance.
#
# The Dataset you'll be given will be in this format:
#
# Date, ZigZagIndicator
#
# Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the previous ZigZag Point.
# The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
#
# Here's the Dataset:
#
# Date, ZigZagIndicator
#
# 2024-03-11 00:00:00, 69020.55\
# 2024-03-13 00:00:00, 73083.5\
# 2024-03-16 00:00:00, 65315.12\
# 2024-03-17 00:00:00, 68390.62\
# 2024-03-19 00:00:00, 61912.77\
# 2024-03-20 00:00:00, 67913.67\
# 2024-03-22 00:00:00, 63778.76\
# 2024-03-25 00:00:00, 69958.81\
# 2024-04-02 00:00:00, 65446.97\
# 2024-04-08 00:00:00, 71631.36\
# 2024-04-09 00:00:00, 69139.02\
# 2024-04-10 00:00:00, 70587.88\
# 2024-04-13 00:00:00, 63821.47\
# 2024-04-14 00:00:00, 65738.73\
# 2024-04-17 00:00:00, 61276.69\
# 2024-04-22 00:00:00, 66837.68\
# 2024-05-01 00:00:00, 58254.01\
# 2024-05-03 00:00:00, 62889.84\
# 2024-05-08 00:00:00, 61187.94\
# 2024-05-09 00:00:00, 63049.96\
# 2024-05-10 00:00:00, 60792.78\
# 2024-05-13 00:00:00, 62901.45\
# 2024-05-14 00:00:00, 61552.79\
# 2024-05-20 00:00:00, 71448.2\
# 2024-05-29 00:00:00, 67578.09\
# 2024-06-04 00:00:00, 70567.77\
# 2024-06-18 00:00:00, 65632.84
#
# Return the answer and the answer only, without adding anything before and after it.

# %% [markdown]
# ---

# %% [markdown]
# ### **Intermediate Between First and Second Node - Checkpoint One**

# %% [markdown]
# **IntermediateOne**
#
# Now reformulate the previous answer in a "Dataset" format, as follows:
#
# Area Type, Area Level, Number of Bounces
#
# Return the Dataset only.
#
# **IntermediateOneBis**
#
# Now reformulate the previous answer in a "Dataset" format, as follows:
#
# Area Type, Area Level, Area Strength, Number of Bounces
#
# Return the Dataset only.

# %% [markdown]
# **Output from IntermediateOneBis**
#
# Resistance, 71000-72000, Strong, 4\
# Resistance, 69000-70000, Weak, 3\
# Support, 63000-64000, Strong, 5\
# Support, 61000-62000, Weak, 3\
# Support, 58000-59000, Minor, 1

# %% [markdown]
# ---

# %% [markdown]
# # **Notes on the Approach below for CoT First Node (Second Attempt):**
#
# Feeding the LLM with High-Low ZigZag Indicator values and Engineering the prompt a bit more has shown better result, especially after employing better Intermediate Prompts, better Question (Instruction) Prompts an better System Prompt.

# %% [markdown]
# ### **Chain of Thought First Node Second Attempt:**

# %% [markdown]
# **First Node Template**
#
# I want you to:
#
# {question}
#
# The Dataset you'll be given will be in this format:
#
# Date, ZigZagIndicator
#
# Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the previous ZigZag Point.\
# The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
#
# Here's the Dataset:
#
# Date, ZigZagIndicator
#
# {context}
#
# Return the answer and the answer only, without adding anything before and after it.

# %% [markdown]
# **First Node Complete**
#
# I want you to:
#
# Identify key levels of price that have been support and resistance by analyzing the frequency and clustering of ZigZag Indicator values around specific price levels.\
# The support and resistance price levels should not be too precise, instead, they need to be rounded up or down, rather than a single specific value.\
# You should also point out how many times the given support or resistance price level has been touched, to emphasize its strength and importance.
#
# The Dataset you'll be given will be in this format:
#
# Date, ZigZagIndicator
#
# Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the previous ZigZag Point.\
# The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
#
# Here's the Dataset:
#
# Date, ZigZagIndicator
#
# 2024-03-11 00:00:00, 69020.55\
# 2024-03-14 00:00:00, 73750.07\
# 2024-03-17 00:00:00, 64545.32\
# 2024-03-18 00:00:00, 68897.13\
# 2024-03-20 00:00:00, 60807.79\
# 2024-03-21 00:00:00, 68199.99\
# 2024-03-22 00:00:00, 62355.37\
# 2024-03-27 00:00:00, 71727.69\
# 2024-03-28 00:00:00, 68895.51\
# 2024-03-31 00:00:00, 71377.78\
# 2024-04-03 00:00:00, 64559.9\
# 2024-04-04 00:00:00, 69291.26\
# 2024-04-05 00:00:00, 66011.48\
# 2024-04-08 00:00:00, 72715.36\
# 2024-04-10 00:00:00, 67503.56\
# 2024-04-11 00:00:00, 71256.23\
# 2024-04-13 00:00:00, 60919.11\
# 2024-04-15 00:00:00, 66878.65\
# 2024-04-17 00:00:00, 59768.59\
# 2024-04-19 00:00:00, 65481.6\
# 2024-04-20 00:00:00, 63172.4\
# 2024-04-22 00:00:00, 67233.96\
# 2024-04-25 00:00:00, 62783.63\
# 2024-04-26 00:00:00, 64789.66\
# 2024-04-27 00:00:00, 62424.72\
# 2024-04-28 00:00:00, 64321.48\
# 2024-05-01 00:00:00, 56555.29\
# 2024-05-06 00:00:00, 65494.9\
# 2024-05-10 00:00:00, 60208.78\
# 2024-05-13 00:00:00, 63422.66\
# 2024-05-14 00:00:00, 61123.77\
# 2024-05-21 00:00:00, 71946.46\
# 2024-05-23 00:00:00, 66356.95\
# 2024-05-25 00:00:00, 69579.32\
# 2024-05-26 00:00:00, 68183.89\
# 2024-05-27 00:00:00, 70597.88\
# 2024-05-29 00:00:00, 67101.49\
# 2024-05-30 00:00:00, 69500.54\
# 2024-05-31 00:00:00, 66633.42\
# 2024-06-05 00:00:00, 71735.41\
# 2024-06-07 00:00:00, 68507.26\
# 2024-06-10 00:00:00, 70146.07\
# 2024-06-11 00:00:00, 66123.6\
# 2024-06-12 00:00:00, 69977.89\
# 2024-06-14 00:00:00, 65056.89\
# 2024-06-17 00:00:00, 67188.32\
# 2024-06-18 00:00:00, 64637.63
#
# Return the answer and the answer only, without adding anything before and after it.

# %% [markdown]
# ---

# %% [markdown]
# ### **Intermediate Between First and Second Node - Checkpoint One**

# %% [markdown]
# **IntermediateOne**
#
# Now reformulate the previous answer in a "Dataset" format, as follows:
#
# Area Type, Area Level, Number of Bounces
#
# Return the Dataset only.

# %% [markdown]
# **Output from IntermediateOne**

# %% [markdown]
# The key support and resistance levels based on the frequency and clustering of ZigZag Indicator values are:
#
# * Support area around 60,000, touched 5 times
# * Support area around 63,000, touched 4 times
# * Support area around 65,000, touched 3 times
# * Resistance area around 69,000, touched 5 times
# * Resistance area around 71,000, touched 4 times
# * Resistance area around 72,000, touched 3 times
#
# Support, 60000, 5
# Support, 63000, 4
# Support, 65000, 3
# Resistance, 69000, 5
# Resistance, 71000, 4
# Resistance, 72000, 3

# %%
Support, 60000, 3
Support, 61000, 4
Support, 65000, 5
Resistance, 69000, 6
Resistance, 71000, 4
Resistance, 72000, 3

# %% [markdown]
# ---

# %% [markdown]
# # **Notes on the Approach below for CoT Second Node (First Attempt):**
#
# This strategy seems to not perform well on the given ZigZag Indicator Data.\
# With that, I mean that the LLM (llama3-70b-8192) is performing incredibly well for the given request, but the Data is simply wrong as it shows swings.\
# An High-Low Dataset approach (Donchian Channel maybe?) would be more suitable.

# %% [markdown]
# ### **Chain of Thought Second Node First Attempt:**

# %% [markdown]
# **Second Node Template**
#
# Now that we have identified support and resistance zones, formatted as follows:
#
# Area Type, Area Level, Area Strength, Number of Bounces
#
# Where Area Type describes whether the Area is of Support or Resistance, Area Level describes the Ranging Area of the given Support or Resistance, Area Strength describes how strong the Support or Resistance has been, and Number of Bounces describes how many times the price has been touching that level.
#
# Here are the Levels, with respective data:
#
# Area Type, Area Level, Area Strength Number of Bounces
#
# {suppandres}
#
# Now, you need to:
#
# {question}
#
# The Dataset you'll be given will be in this format:
#
# Date, ZigZagIndicator
#
# Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the Previous ZigZag Point.
# The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
#
# Here's the Dataset:
#
# Date, ZigZagIndicator
#
# {context}
#
# Return the answer and the answer only, without adding anything before and after it.

# %% [markdown]
# **Second Node Complete**
#
# Now that we have identified support and resistance zones, formatted as follows:
#
# Area Type, Area Level, Area Strength, Number of Bounces
#
# Where Area Type describes whether the Area is of Support or Resistance, Area Level or Range describes either the Ranging Area or specific level of the given Support or Resistance, and Number of Bounces describes how many times the price has been touching that level emphasizing its strength.
#
# Here are the Levels, with respective data:
#
# Area Type, Area Level or Range, Number of Bounces
#
# Support, 60000-61000, 7
# Support, 65000, 5
# Resistance, 69000, 6
# Resistance, 71000-72000, 7
#
# At this Stage, you need to:
#
# Look for all areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range, which indicate a Trading Range preceding a potential breakout or reversal, or simply a pausing phase.\
# The identified consolidation or congestion areas should not be too precise and are not specific levels, instead, they need to be rounded up or down and indicating an area range, rather than a single specific value.\
# You should also point out what kind of consolidation or congestion happened in that specific area, taking as context the previous movement that preceded the consolidation or congestion and the date when the consolidation or congestion started as well as how much time the price has spent in that Area.
#
# For this Specific Task, you'll given 2 Datasets.
# The first Dataset is the ZigZag Indicator Data, that represents the price swings, while the second one is the Average True Range, which is the range from high to low of the specific candles and you'll use it to identify where the price has been compressing, since lower values in the Average True Range mean more compression in prices and less excursion between highs and lows.
#
# ZigZag Indicator Dataset format:
#
# Date, ZigZagIndicator
#
# Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the Previous ZigZag Point. The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.
#
# Here's the Dataset:
#
# Date, ZigZagIndicator
#
# 2024-03-11 00:00:00, 69020.55\
# 2024-03-14 00:00:00, 73750.07\
# 2024-03-17 00:00:00, 64545.32\
# 2024-03-18 00:00:00, 68897.13\
# 2024-03-20 00:00:00, 60807.79\
# 2024-03-21 00:00:00, 68199.99\
# 2024-03-22 00:00:00, 62355.37\
# 2024-03-27 00:00:00, 71727.69\
# 2024-03-28 00:00:00, 68895.51\
# 2024-03-31 00:00:00, 71377.78\
# 2024-04-03 00:00:00, 64559.9\
# 2024-04-04 00:00:00, 69291.26\
# 2024-04-05 00:00:00, 66011.48\
# 2024-04-08 00:00:00, 72715.36\
# 2024-04-10 00:00:00, 67503.56\
# 2024-04-11 00:00:00, 71256.23\
# 2024-04-13 00:00:00, 60919.11\
# 2024-04-15 00:00:00, 66878.65\
# 2024-04-17 00:00:00, 59768.59\
# 2024-04-19 00:00:00, 65481.6\
# 2024-04-20 00:00:00, 63172.4\
# 2024-04-22 00:00:00, 67233.96\
# 2024-04-25 00:00:00, 62783.63\
# 2024-04-26 00:00:00, 64789.66\
# 2024-04-27 00:00:00, 62424.72\
# 2024-04-28 00:00:00, 64321.48\
# 2024-05-01 00:00:00, 56555.29\
# 2024-05-06 00:00:00, 65494.9\
# 2024-05-10 00:00:00, 60208.78\
# 2024-05-13 00:00:00, 63422.66\
# 2024-05-14 00:00:00, 61123.77\
# 2024-05-21 00:00:00, 71946.46\
# 2024-05-23 00:00:00, 66356.95\
# 2024-05-25 00:00:00, 69579.32\
# 2024-05-26 00:00:00, 68183.89\
# 2024-05-27 00:00:00, 70597.88\
# 2024-05-29 00:00:00, 67101.49\
# 2024-05-30 00:00:00, 69500.54\
# 2024-05-31 00:00:00, 66633.42\
# 2024-06-05 00:00:00, 71735.41\
# 2024-06-07 00:00:00, 68507.26\
# 2024-06-10 00:00:00, 70146.07\
# 2024-06-11 00:00:00, 66123.6\
# 2024-06-12 00:00:00, 69977.89\
# 2024-06-14 00:00:00, 65056.89\
# 2024-06-17 00:00:00, 67188.32\
# 2024-06-18 00:00:00, 64637.63
#
# AverageTrueRange Indicator Dataset format:
#
# Date, AverageTrueRange
#
# Where, Date is the date of the specific AverageTrueRange value, and AverageTrueRange is the excursion between high and low for that specific Date.
#
# Here's the Dataset:
#
# Date, AverageTrueRange:
#
# 2024-03-11 00:00:00, 5655.83\
# 2024-03-12 00:00:00, 4096.8\
# 2024-03-13 00:00:00, 2303.38\
# 2024-03-14 00:00:00, 5187.05\
# 2024-03-15 00:00:00, 6726.44\
# 2024-03-16 00:00:00, 5244.88\
# 2024-03-17 00:00:00, 4300.4\
# 2024-03-18 00:00:00, 2302.91\
# 2024-03-19 00:00:00, 6570.75\
# 2024-05-26 00:00:00, 1322.34\
# 2024-05-27 00:00:00, 2365.38\
# 2024-05-28 00:00:00, 2287.48\
# 2024-05-29 00:00:00, 1750.97\
# 2024-05-30 00:00:00, 2382.46\
# 2024-05-31 00:00:00, 2366.14\
# 2024-06-01 00:00:00, 453.57\
# 2024-06-02 00:00:00, 1093.64\
# 2024-06-03 00:00:00, 2640.98\
# 2024-06-04 00:00:00, 2482.77\
# 2024-06-05 00:00:00, 1344.7\
# 2024-06-06 00:00:00, 1506.61\
# 2024-06-07 00:00:00, 3400.59\
# 2024-06-08 00:00:00, 322.58\
# 2024-06-09 00:00:00, 656.68\
# 2024-06-10 00:00:00, 913.65\
# 2024-06-11 00:00:00, 3425.81\
# 2024-06-12 00:00:00, 3075.44\
# 2024-06-13 00:00:00, 2061.22\
# 2024-06-14 00:00:00, 2237.75\
# 2024-06-15 00:00:00, 530.41\
# 2024-06-16 00:00:00, 876.59\
# 2024-06-17 00:00:00, 2093.36\
# 2024-06-18 00:00:00, 1853.59
#
# Return the answer and the answer only, without adding anything before and after it.

# %% [markdown]
# ---

# %% [markdown]
# ### **Intermediate Between Second and Third Node - Checkpoint Two**

# %% [markdown]
# **IntermediateTwo**
#
# Now reformulate the previous answer in a "Dataset" format, as follows:
#
# Area Type, Area Range, Area Start Date, Area Time Duration
#
# Return the Dataset only.

# %% [markdown]
# **Output from IntermediateTwo**
#
# Consolidation, 69000-70000, 2024-03-11, 7\
# Consolidation, 63000-64000, 2024-05-03, 10\
# Congestion, 61000-62000, 2024-05-08, 5

# %% [markdown]
# ---

# %% [markdown]
# # **Notes on the Approach below for CoT Second Node (Second Attempt):**
#
# For the second attempt the contextual data will be XXX.\
# This shows XXX performances and better identifications of congestion zones.

# %% [markdown]
# ### **Chain of Thought Second Node Second Attempt:**

# %%
#Test

Look for all areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range, which can indicate a potential breakout or reversal, or simply a trading a range. The identified consolidation or congestion areas should not be too precise, instead, they need to be rounded up or down, indicating an area, rather than a single specific value. You should also point out what kind of consolidation or congestion happened in that specific area, taking as context the previous movement that preceded the consolidation or congestion.
Lastly, you will provide the date when the consolidation or congestion started as well as how much time the price has spent in that Area.
# Out:
#   Cell In[5], line 3
#     Look for all areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range, which can indicate a potential breakout or reversal, or simply a trading a range. The identified consolidation or congestion areas should not be too precise, instead, they need to be rounded up or down, indicating an area, rather than a single specific value. You should also point out what kind of consolidation or congestion happened in that specific area, taking as context the previous movement that preceded the consolidation or congestion.
#          ^
# SyntaxError: invalid syntax

# %%
I want you to:

Identify key levels of price that have been support and resistance by analyzing the frequency and clustering of ZigZag Indicator values around specific price levels.
The support and resistance price levels should not be too precise, instead, they need to be rounded up or down, rather than a single specific value.
You should also point out how many times the given support or resistance price level has been touched, to emphasize its strength and importance.



The Dataset you'll be given will be in this format:

Date, ZigZagIndicator

Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the previous ZigZag Point.
The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.

Here's the Dataset:

Date, ZigZagIndicator

2024-03-11 00:00:00, 69020.55
2024-03-14 00:00:00, 73750.07
2024-03-17 00:00:00, 64545.32
2024-03-18 00:00:00, 68897.13
2024-03-20 00:00:00, 60807.79
2024-03-21 00:00:00, 68199.99
2024-03-22 00:00:00, 62355.37
2024-03-27 00:00:00, 71727.69
2024-03-28 00:00:00, 68895.51
2024-03-31 00:00:00, 71377.78
2024-04-03 00:00:00, 64559.9
2024-04-04 00:00:00, 69291.26
2024-04-05 00:00:00, 66011.48
2024-04-08 00:00:00, 72715.36
2024-04-10 00:00:00, 67503.56
2024-04-11 00:00:00, 71256.23
2024-04-13 00:00:00, 60919.11
2024-04-15 00:00:00, 66878.65
2024-04-17 00:00:00, 59768.59
2024-04-19 00:00:00, 65481.6
2024-04-20 00:00:00, 63172.4
2024-04-22 00:00:00, 67233.96
2024-04-25 00:00:00, 62783.63
2024-04-26 00:00:00, 64789.66
2024-04-27 00:00:00, 62424.72
2024-04-28 00:00:00, 64321.48
2024-05-01 00:00:00, 56555.29
2024-05-06 00:00:00, 65494.9
2024-05-10 00:00:00, 60208.78
2024-05-13 00:00:00, 63422.66
2024-05-14 00:00:00, 61123.77
2024-05-21 00:00:00, 71946.46
2024-05-23 00:00:00, 66356.95
2024-05-25 00:00:00, 69579.32
2024-05-26 00:00:00, 68183.89
2024-05-27 00:00:00, 70597.88
2024-05-29 00:00:00, 67101.49
2024-05-30 00:00:00, 69500.54
2024-05-31 00:00:00, 66633.42
2024-06-05 00:00:00, 71735.41
2024-06-07 00:00:00, 68507.26
2024-06-10 00:00:00, 70146.07
2024-06-11 00:00:00, 66123.6
2024-06-12 00:00:00, 69977.89
2024-06-14 00:00:00, 65056.89
2024-06-17 00:00:00, 67188.32
2024-06-18 00:00:00, 64637.63

Return the answer and the answer only, without adding anything before and after it.

# %%
I want you to:

Look for all areas of congestion or consolidation, where the ZigZag Indicator values are trading within a narrow range and the True Range values are compressing, which indicate a Trading Range preceding a potential breakout or reversal, or simply a pausing phase.
The identified consolidation or congestion areas should not be too precise and are not specific levels, instead, they need to be rounded up or down and indicating an area range, rather than a single specific value.
You should also point out the date when the consolidation or congestion started as well as how much time the price has spent in that Area.

For this Specific Task, you'll given 2 Datasets. 
The first Dataset is the ZigZag Indicator Data, that represents the price swings, while the second one is the True Range, which is the range from high to low of the specific candles and you'll use it to identify where the price has been compressing, since lower values in the True Range mean more compression in prices and less excursion between highs and lows.

ZigZag Indicator Dataset format:

Date, ZigZagIndicator

Where, Date is the date when the ZigZag Indicator Swing has completed and ZigZagIndicator is the actual point of Swing from the Previous ZigZag Point. The Dataset given will not contain any candlesticks, and the expected final goal will be an overview rather than a technical analysis.

